# %% [markdown]
# ## Sentiment analysis
# -----
# ### Importing the cleaned data
# ---

# %%
# %store -r game_df_cleaned
# %store -r swords_df_cleaned

# %store -r game_text_cleaned
# %store -r swords_text_cleaned

# %%
# !pip install afinn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: afinn in /home/suru/.local/lib/python3.10/site-packages (0.1)

# %%
from afinn import Afinn as Afinn
import re
from siuba import *
import pandas as pd
from wordcloud import *

# %%
afinn = Afinn()

game_text_str = ""
for _list in game_text_cleaned:
    for string in _list:
        game_text_str += string + ' '

game_df_cleaned = pd.DataFrame({
    "word": game_text_str.split()
})

swords_text_str = ""
for _list in swords_text_cleaned:
    for string in _list:
        swords_text_str += string + ' '

swords_df_cleaned = pd.DataFrame({
    "word": swords_text_str.split()
})

word_scores_swords = [afinn.score(word_) for word_ in swords_df_cleaned['word']]
swords_df_cleaned = swords_df_cleaned.assign(word_score = word_scores_swords)
# print(swords_df_cleaned)

word_scores_game = [afinn.score(word) for word in game_df_cleaned['word']]
game_df_cleaned = game_df_cleaned.assign(word_score = word_scores_game)
# print(game_df_cleaned)

# %% [markdown]
# ### Function to break first book into chapters
# ------
# #### Chapter 0 ----> PROLOGUE

# %%
chapters_first_book = ["BRAN", "CATELYN", "DAENERYS", "EDDARD", "JON", "ARYA", "TYRION", "SANSA"]
chapters_second_book = ["JAIME", "DAVOS", "SAMWELL", "BRAN", "CATELYN", "DAENERYS", "JON", "ARYA", "TYRION", "SANSA"]

# CHAPTER 0  -------> PROLOGUE
def select_chapter(dataframe, chapters):
    chapter_list = []
    curr_chapter = 0
    flag = False
    flag_epilogue = 0
    for index, row in dataframe.iterrows():
        if flag:
            curr_chapter = curr_chapter
        elif re.search("HOUSE", row['word']) and "SAMWELL" not in chapters:
            flag = True
        elif re.search("EPILOGUE", row['word']):
            flag_epilogue += 1
            if flag_epilogue > 1:
                flag = True
        elif row['word'] in chapters:
            curr_chapter += 1
        chapter_list.append(curr_chapter)
    return chapter_list

# %% [markdown]
# ### Breaking first book in chapters ( A Game of Thrones )
# ---

# %%
game_df_cleaned = game_df_cleaned.assign(chapter = select_chapter(game_df_cleaned, chapters_first_book))
game_df_cleaned.head(150000)
# Out:
#               word  word_score  chapter
# 0             GAME         0.0        0
# 1               OF         0.0        0
# 2          THRONES         0.0        0
# 3             Book         0.0        0
# 4             Song         0.0        0
# ...            ...         ...      ...
# 149995       steel         0.0       72
# 149996       music         0.0       72
# 149997        grew         0.0       72
# 149998      louder         0.0       72
# 149999  approached         0.0       72
#
# [150000 rows x 3 columns]

# %% [markdown]
# ### Breaking the second book in chapters ( A Storm of Swords )
# ---

# %%
swords_df_cleaned = swords_df_cleaned.assign(chapter = select_chapter(swords_df_cleaned, chapters_second_book))
swords_df_cleaned.head(150000)
# Out:
#            word  word_score  chapter
# 0         STORM         0.0        0
# 1            OF         0.0        0
# 2        SWORDS         0.0        0
# 3          Book         0.0        0
# 4          Song         0.0        0
# ...         ...         ...      ...
# 149995     skin         0.0       80
# 149996  striped         0.0       80
# 149997   zorses         0.0       80
# 149998    Jogos         0.0       80
# 149999     rode         0.0       80
#
# [150000 rows x 3 columns]

# %% [markdown]
# ### Chapter Scores for Storm of Swords (3rd book)
# ---

# %%
swords_df_cleaned_grouped = group_by(swords_df_cleaned, 'chapter')
summarized_ss_df_swords = summarize(swords_df_cleaned_grouped, chapter_score = _.word_score.sum())
summarized_ss_df_swords.head()
# Out:
#    chapter  chapter_score
# 0        0         -238.0
# 1        1         -113.0
# 2        2          -14.0
# 3        3          -94.0
# 4        4          -69.0

# %% [markdown]
# ### Chapter Scores for A Game of Thrones (1st book)
# ---

# %%
game_df_cleaned_grouped = group_by(game_df_cleaned, 'chapter')
summarized_ss_df = summarize(game_df_cleaned_grouped, chapter_score = _.word_score.sum())
summarized_ss_df.head()
# Out:
#    chapter  chapter_score
# 0        0          -56.0
# 1        1          -90.0
# 2        2            2.0
# 3        3            6.0
# 4        4           -9.0

# %% [markdown]
# ### Generating a WordCloud based on chapters 50 & 51 (The Red Wedding)
# ----

# %%
from matplotlib import pyplot as plt
import numpy as np
from PIL import Image

mask = np.array(Image.open("../resources/map.png"))
mask[mask == 0] = 255

red_wedding = swords_df_cleaned[ (swords_df_cleaned['chapter'] >= 50) & (swords_df_cleaned['chapter'] <= 51) ]
text_str = ""
for str in red_wedding['word']:
    text_str += str + " "

cloudy_cloud = WordCloud(background_color="#303030", width=1600, height=800, colormap='Set1', max_words=1000, mask=mask).generate(text_str)

plt.figure( figsize=(20,10), facecolor='k')
plt.imshow(cloudy_cloud)
plt.axis("off")
plt.tight_layout(pad=0)

# %% [markdown]
# ### Time to compare Afinn results to NRCLex analysis
# ------

# %%
# !pip install NRCLex
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting NRCLex
#   Downloading NRCLex-3.0.0.tar.gz (396 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 396.4/396.4 kB 3.3 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Collecting textblob
#   Downloading textblob-0.17.1-py2.py3-none-any.whl (636 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 636.8/636.8 kB 8.6 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: nltk>=3.1 in /home/suru/.local/lib/python3.10/site-packages (from textblob->NRCLex) (3.7)
# Requirement already satisfied: tqdm in /home/suru/.local/lib/python3.10/site-packages (from nltk>=3.1->textblob->NRCLex) (4.64.0)
# Requirement already satisfied: regex>=2021.8.3 in /home/suru/.local/lib/python3.10/site-packages (from nltk>=3.1->textblob->NRCLex) (2022.6.2)
# Requirement already satisfied: click in /usr/lib/python3/dist-packages (from nltk>=3.1->textblob->NRCLex) (8.0.3)
# Requirement already satisfied: joblib in /home/suru/.local/lib/python3.10/site-packages (from nltk>=3.1->textblob->NRCLex) (1.1.0)
# Building wheels for collected packages: NRCLex
#   Building wheel for NRCLex (setup.py) ... done
#   Created wheel for NRCLex: filename=NRCLex-3.0.0-py3-none-any.whl size=43329 sha256=ba6cccc59d8d3a55c432ee4fbd1d9a5069206f3865328be7432800509d2e7148
#   Stored in directory: /home/suru/.cache/pip/wheels/d2/10/44/6abfb1234298806a145fd6bcaec8cbc712e88dd1cd6cb242fa
# Successfully built NRCLex
# Installing collected packages: textblob, NRCLex
# Successfully installed NRCLex-3.0.0 textblob-0.17.1

# %%
from nrclex import NRCLex

game_object = NRCLex(game_text_str)
swords_object = NRCLex(swords_text_str)

# %% [markdown]
# ## Creating the NRCLex for both game_df and swords_df
# ------

# %%
game_nrclex = [NRCLex(elem).top_emotions for elem in game_df_cleaned['word']]
# Out:
# [[('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('anticipation', 1.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('trust', 0.25), ('positive', 0.25), ('joy', 0.25), ('anticipation', 0.25)],
#  [('sadness', 1.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.25), ('surprise', 0.25), ('negative', 0.25), ('sadness', 0.25)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('trust', 1.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('trust', 1.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('anger', 0.5), ('negative', 0.5)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('trust', 0.16666666666666666),
#   ('positive', 0.16666666666666666),
#   ('negative', 0.16666666666666666),
#   ('sadness', 0.16666666666666666),
#   ('joy', 0.16666666666666666),
#   ('anticipation', 0.16666666666666666)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('trust', 0.2),
#   ('positive', 0.2),
#   ('sadness', 0.2),
#   ('joy', 0.2),
#   ('anticipation', 0.2)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('trust', 0.5), ('positive', 0.5)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('anticipation', 1.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('positive', 1.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('anger', 0.5), ('negative', 0.5)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('negative', 0.5), ('sadness', 0.5)],
#  [('fear', 0.25), ('anger', 0.25), ('negative', 0.25), ('disgust', 0.25)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('negative', 1.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('positive', 1.0)],
#  [('sadness', 1.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.3333333333333333),
#   ('negative', 0.3333333333333333),
#   ('anticipation', 0.3333333333333333)],
#  [('anger', 1.0)],
#  [('fear', 0.25),
#   ('negative', 0.25),
#   ('sadness', 0.25),
#   ('anticipation', 0.25)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('anticipation', 1.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('disgust', 1.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('trust', 0.5), ('positive', 0.5)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.14285714285714285),
#   ('anger', 0.14285714285714285),
#   ('trust', 0.14285714285714285),
#   ('positive', 0.14285714285714285),
#   ('negative', 0.14285714285714285),
#   ('sadness', 0.14285714285714285),
#   ('joy', 0.14285714285714285)],
#  [('sadness', 1.0)],
#  [('fear', 0.3333333333333333),
#   ('sadness', 0.3333333333333333),
#   ('anticipation', 0.3333333333333333)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
# ...
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('disgust', 1.0)],
#  [('negative', 0.5), ('sadness', 0.5)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('sadness', 1.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('disgust', 1.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.3333333333333333),
#   ('trust', 0.3333333333333333),
#   ('positive', 0.3333333333333333)],
#  [('fear', 1.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('trust', 0.25), ('positive', 0.25), ('joy', 0.25), ('anticipation', 0.25)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('negative', 0.5), ('sadness', 0.5)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('anticipation', 1.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.3333333333333333),
#   ('anger', 0.3333333333333333),
#   ('negative', 0.3333333333333333)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('anticipation', 1.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('positive', 1.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('trust', 0.25), ('positive', 0.25), ('joy', 0.25), ('anticipation', 0.25)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('positive', 1.0)],
#  [('surprise', 1.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('sadness', 1.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.1111111111111111),
#   ('trust', 0.1111111111111111),
#   ('surprise', 0.1111111111111111),
#   ('positive', 0.1111111111111111),
#   ('negative', 0.1111111111111111),
#   ('sadness', 0.1111111111111111),
#   ('disgust', 0.1111111111111111),
#   ('joy', 0.1111111111111111),
#   ('anticipation', 0.1111111111111111)],
#  [('negative', 0.5), ('disgust', 0.5)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('sadness', 1.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('trust', 1.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.5), ('negative', 0.5)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('negative', 1.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('negative', 1.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  [('fear', 0.0),
#   ('anger', 0.0),
#   ('anticip', 0.0),
#   ('trust', 0.0),
#   ('surprise', 0.0),
#   ('positive', 0.0),
#   ('negative', 0.0),
#   ('sadness', 0.0),
#   ('disgust', 0.0),
#   ('joy', 0.0)],
#  ...]

# %%
swords_nrclex = [NRCLex(elem).top_emotions for elem in swords_df_cleaned['word']]

# %%
game_df_ = game_df_cleaned.copy()
game_df_ = game_df_.assign(chapter = select_chapter(game_df_, chapters_first_book))
game_df_ = game_df_.assign(sentiment = game_nrclex)
game_df_
# Out:
#             word  word_score  chapter  \
# 0           GAME         0.0        0
# 1             OF         0.0        0
# 2        THRONES         0.0        0
# 3           Book         0.0        0
# 4           Song         0.0        0
# ...          ...         ...      ...
# 277961  Daenerys         0.0       72
# 277962      maid         0.0       72
# 277963  thirteen         0.0       72
# 277964  previous         0.0       72
# 277965     Table         0.0       72
#
#                                                 sentiment
# 0       [(fear, 0.0), (anger, 0.0), (anticip, 0.0), (t...
# 1       [(fear, 0.0), (anger, 0.0), (anticip, 0.0), (t...
# 2       [(fear, 0.0), (anger, 0.0), (anticip, 0.0), (t...
# 3       [(fear, 0.0), (anger, 0.0), (anticip, 0.0), (t...
# 4       [(fear, 0.0), (anger, 0.0), (anticip, 0.0), (t...
# ...                                                   ...
# 277961  [(fear, 0.0), (anger, 0.0), (anticip, 0.0), (t...
# 277962  [(fear, 0.0), (anger, 0.0), (anticip, 0.0), (t...
# 277963  [(fear, 0.0), (anger, 0.0), (anticip, 0.0), (t...
# 277964  [(fear, 0.0), (anger, 0.0), (anticip, 0.0), (t...
# 277965  [(fear, 0.0), (anger, 0.0), (anticip, 0.0), (t...
#
# [277966 rows x 4 columns]

# %%
swords_df_ = swords_df_cleaned.copy()
swords_df_ = swords_df_.assign(chapter = select_chapter(swords_df_, chapters_second_book))
swords_df_ = swords_df_.assign(sentiment = swords_nrclex)
swords_df_
# Out:
#             word  word_score  chapter  \
# 0          STORM         0.0        0
# 1             OF         0.0        0
# 2         SWORDS         0.0        0
# 3           Book         0.0        0
# 4           Song         0.0        0
# ...          ...         ...      ...
# 226347  daughter         0.0       80
# 226348     great         3.0       80
# 226349  nineteen         0.0       80
# 226350  previous         0.0       80
# 226351     Table         0.0       80
#
#                                                 sentiment
# 0       [(fear, 0.0), (anger, 0.0), (anticip, 0.0), (t...
# 1       [(fear, 0.0), (anger, 0.0), (anticip, 0.0), (t...
# 2       [(fear, 0.0), (anger, 0.0), (anticip, 0.0), (t...
# 3       [(fear, 0.0), (anger, 0.0), (anticip, 0.0), (t...
# 4       [(fear, 0.0), (anger, 0.0), (anticip, 0.0), (t...
# ...                                                   ...
# 226347                      [(positive, 0.5), (joy, 0.5)]
# 226348  [(fear, 0.0), (anger, 0.0), (anticip, 0.0), (t...
# 226349  [(fear, 0.0), (anger, 0.0), (anticip, 0.0), (t...
# 226350  [(fear, 0.0), (anger, 0.0), (anticip, 0.0), (t...
# 226351  [(fear, 0.0), (anger, 0.0), (anticip, 0.0), (t...
#
# [226352 rows x 4 columns]

# %% [markdown]
# ## Calculating word_score / chapter in order to compare with Afinn
# -------

# %%
test_per_chapter_game = game_df_.groupby('chapter').agg({
                             'word': ', '.join,
                             'word_score':'sum' }).reset_index() 
test_per_chapter_game[test_per_chapter_game['chapter'] == 51]
test_per_chapter_game
# Out:
#     chapter                                               word  word_score
# 51       51  SANSA, chose, simple, dress, dark, grey, plain...        39.0

# %%
test_per_chapter_swords = swords_df_.groupby('chapter').agg({
                             'word': ', '.join,
                             'word_score':'sum' }).reset_index() 
test_per_chapter_swords[test_per_chapter_swords['chapter'] == 51]
test_per_chapter_swords

# %%
import nltk
# nltk.download('vader_lexicon')
from nltk.sentiment import SentimentIntensityAnalyzer
from siuba import *
sia = SentimentIntensityAnalyzer()
scores = sia.polarity_scores('Yay')

# %%
list_game_sentiments = ['positive' if sia.polarity_scores(word)['compound'] > 0 else 'negative' if sia.polarity_scores(word)['compound'] < 0 else 'neutral' for word in game_df_['word']]
list_swords_sentiments = ['positive' if sia.polarity_scores(word)['compound'] > 0 else 'negative' if sia.polarity_scores(word)['compound'] < 0 else 'neutral' for word in swords_df_['word']]

# %%
game_df_ = game_df_.assign(nltk_sentiment = list_game_sentiments)
swords_df_ = swords_df_.assign(nltk_sentiment = list_swords_sentiments)

# %%
filtered_neg = filter(swords_df_, _.nltk_sentiment == 'negative', _.chapter == 51)
filtered_pos = filter(swords_df_, _.nltk_sentiment == 'positive', _.chapter == 51)
total = pd.concat([filtered_neg, filtered_pos])

# %% [markdown]
# ## Creating wordclouds for the obtained data
# -----
# ###  First of all, the negative emotions of the Chapter 51(Red Wedding)
# -----

# %%
from matplotlib import pyplot as plt
import numpy as np
from PIL import Image

mask = np.array(Image.open("../resources/map.png"))
mask[mask == 0] = 255
this_is_it = count(filtered_neg, 'word').sort_values('n', ascending=False).set_index('word').to_dict()

cloudy_cloud = WordCloud(background_color="#303030", width=1600, height=800, colormap='Set1', max_words=1000, mask=mask)
cloudy_cloud.generate_from_frequencies(this_is_it['n'])

plt.figure( figsize=(20,10), facecolor='k')
plt.imshow(cloudy_cloud)
plt.axis("off")
plt.tight_layout(pad=0)

# %% [markdown]
# ###  Secondly, the positive emotions of the Chapter 51(Red Wedding)
# -----

# %%
from matplotlib import pyplot as plt
import numpy as np
from PIL import Image

mask = np.array(Image.open("../resources/map.png"))
mask[mask == 0] = 255
this_is_it = count(filtered_pos, 'word').sort_values('n', ascending=False).set_index('word').to_dict()

cloudy_cloud = WordCloud(background_color="#303030", width=1600, height=800, colormap='Set1', max_words=1000, mask=mask)
cloudy_cloud.generate_from_frequencies(this_is_it['n'])

plt.figure( figsize=(20,10), facecolor='k')
plt.imshow(cloudy_cloud)
plt.axis("off")
plt.tight_layout(pad=0)

# %% [markdown]
# ###  Finally, the mixed emotions of the Chapter 51(Red Wedding)
# -----

# %%
from matplotlib import pyplot as plt
import numpy as np
from PIL import Image

mask = np.array(Image.open("../resources/map.png"))
mask[mask == 0] = 255
this_is_it = count(total, 'word').sort_values('n', ascending=False).set_index('word').to_dict()

cloudy_cloud = WordCloud(background_color="#303030", width=1600, height=800, colormap='Set1', max_words=1000, mask=mask)
cloudy_cloud.generate_from_frequencies(this_is_it['n'])

plt.figure( figsize=(20,10), facecolor='k')
plt.imshow(cloudy_cloud)
plt.axis("off")
plt.tight_layout(pad=0)

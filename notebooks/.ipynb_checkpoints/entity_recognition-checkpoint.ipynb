# %% [markdown]
# ## Named entity recognition (NER)
# ----

# %% [markdown]
# ### Importing the data we need
# ----

# %%
# %store -r game_text_cleaned
# %store -r swords_text_cleaned

# %store -r game_df_cleaned
# %store -r swords_df_cleaned

# %%
# !pip install wikipedia
# !pip install --upgrade pip
# !pip install textacy
# !python3 -m spacy download en_core_web_lg
import pandas as pd
import spacy

nlp = spacy.load('en_core_web_lg')
nlp.max_length = 3000000

# %% [markdown]
# ### Using Spacy to create a method extracting all the characters
# -------

# %%
def get_characters(text_cleaned):
    
    text_string = ""
    for _list in text_cleaned:
        for string in _list:
            text_string += string + ' '
    
    characters_list = [{"name" : "Default", "count" : -1}]
    
    doc = nlp(text_string)
    for ent in doc.ents:
        index = next((i for i, item in enumerate(characters_list) if item["name"] == ent.text), None)
        if index is None and ent.label_ == "PERSON":
            characters_list.append({"name" : ent.text, "count" : 1});
        elif index is not None and ent.label_ == "PERSON":
            characters_list[index]["count"] += 1
    
    return characters_list

# %% [markdown]
# ## Sort the obtained characters list
# ----
# - We obtain something like [{}] --> list a of dictionaries
# - each dictionary has a field "name" and a field "count", therefore we will sort our dictionaries list by the count of the characters in reverse order (most common characters come first)

# %%
characters_list = get_characters(game_text_cleaned)
characters_list = sorted(characters_list, key=lambda x: x['count'], reverse=True)

# %%
print(characters_list)
# Out:
# [{'name': 'Tyrion', 'count': 1049}, {'name': 'Ned', 'count': 791}, {'name': 'Jon', 'count': 780}, {'name': 'Catelyn', 'count': 645}, {'name': 'Dany', 'count': 612}, {'name': 'Jaime', 'count': 445}, {'name': 'Robb', 'count': 411}, {'name': 'Robert', 'count': 341}, {'name': 'Arya', 'count': 304}, {'name': 'Joffrey', 'count': 259}, {'name': 'Sam', 'count': 259}, {'name': 'Stannis', 'count': 214}, {'name': 'Lannister', 'count': 203}, {'name': 'Cersei', 'count': 153}, {'name': 'Lysa', 'count': 147}, {'name': 'Luwin', 'count': 137}, {'name': 'Khal Drogo', 'count': 133}, {'name': 'Tywin', 'count': 114}, {'name': 'Rodrik', 'count': 108}, {'name': 'Bronn', 'count': 108}, {'name': 'Tyrion Lannister', 'count': 106}, {'name': 'Gregor', 'count': 90}, {'name': 'Brienne', 'count': 90}, {'name': 'Littlefinger', 'count': 88}, {'name': 'Grenn', 'count': 87}, {'name': 'Eddard Stark', 'count': 79}, {'name': 'Stark', 'count': 77}, {'name': 'Hodor', 'count': 71}, {'name': 'Jon Snow', 'count': 70}, {'name': 'Mance', 'count': 69}, {'name': 'Barristan', 'count': 65}, {'name': 'Viserys', 'count': 64}, {'name': 'Ygritte', 'count': 63}, {'name': 'Sandor Clegane', 'count': 61}, {'name': 'Petyr', 'count': 59}, {'name': 'Mormont', 'count': 59}, {'name': 'Starks', 'count': 58}, {'name': 'Catelyn Stark', 'count': 58}, {'name': 'Renly', 'count': 56}, {'name': 'Kevan', 'count': 56}, {'name': 'Lannisters', 'count': 53}, {'name': 'Drogo', 'count': 52}, {'name': 'Walder', 'count': 51}, {'name': 'Jon Arryn', 'count': 50}, {'name': 'Jaime Lannister', 'count': 50}, {'name': 'Meera', 'count': 50}, {'name': 'Theon Greyjoy', 'count': 49}, {'name': 'Grace', 'count': 49}, {'name': 'Hound', 'count': 48}, {'name': 'Tywin Lannister', 'count': 48}, {'name': 'Shae', 'count': 48}, {'name': 'Tom', 'count': 47}, {'name': 'Gilly', 'count': 47}, {'name': 'Dornish', 'count': 46}, {'name': 'Varys', 'count': 44}, {'name': 'Mirri Maz Duur', 'count': 43}, {'name': 'Cleos', 'count': 42}, {'name': 'Brandon', 'count': 41}, {'name': 'Jeyne', 'count': 41}, {'name': 'Cersei Lannister', 'count': 40}, {'name': 'Vale', 'count': 39}, {'name': 'Mirri Maz', 'count': 39}, {'name': 'Kingsguard', 'count': 38}, {'name': 'Samwell Tarly', 'count': 38}, {'name': 'Mord', 'count': 38}, {'name': 'Ned Stark', 'count': 37}, {'name': 'Bowen Marsh', 'count': 37}, {'name': 'Tommen', 'count': 36}, {'name': 'Greatjon', 'count': 36}, {'name': 'Bolton', 'count': 36}, {'name': 'Jory', 'count': 35}, {'name': 'Tyrell', 'count': 35}, {'name': 'Boros', 'count': 34}, {'name': 'Alliser Thorne', 'count': 34}, {'name': 'Roose Bolton', 'count': 33}, {'name': 'Robert Baratheon', 'count': 32}, {'name': 'Janos Slynt', 'count': 32}, {'name': 'Loras', 'count': 31}, {'name': 'Chett', 'count': 31}, {'name': 'Doreah', 'count': 30}, {'name': 'Gregor Clegane', 'count': 30}, {'name': 'Dontos', 'count': 30}, {'name': 'Donal Noye', 'count': 28}, {'name': 'Jaremy', 'count': 28}, {'name': 'Waymar', 'count': 27}, {'name': 'Irri', 'count': 27}, {'name': 'Jorah', 'count': 27}, {'name': 'Mance Rayder', 'count': 27}, {'name': 'Addam', 'count': 27}, {'name': 'Hoster', 'count': 27}, {'name': 'Qotho', 'count': 26}, {'name': 'Tormund', 'count': 26}, {'name': 'Lem', 'count': 26}, {'name': 'Janos', 'count': 25}, {'name': 'Pyke', 'count': 25}, {'name': 'Kingslayer', 'count': 24}, {'name': 'Davos', 'count': 24}, {'name': 'Theon', 'count': 23}, {'name': 'Aegon', 'count': 23}, {'name': 'Robb Stark', 'count': 23}, {'name': 'Margaery', 'count': 23}, {'name': 'Benjen Stark', 'count': 22}, {'name': 'Nymeria', 'count': 22}, {'name': 'Rickon', 'count': 22}, {'name': 'Lady Stark', 'count': 21}, {'name': 'Meryn', 'count': 21}, {'name': 'Lady Lysa', 'count': 21}, {'name': 'Greyjoy', 'count': 20}, {'name': 'Lysa Arryn', 'count': 20}, {'name': 'Mya', 'count': 20}, {'name': 'Ser Vardis', 'count': 20}, {'name': 'Samwell', 'count': 19}, {'name': 'Vaes Dothrak', 'count': 18}, {'name': 'Jeyne Poole', 'count': 18}, {'name': 'Prince Joffrey', 'count': 18}, {'name': 'Thorne' ...

# %% [markdown]
# ## Create a method to manipulate our current character list
# -----
# - Now we have a list with all the characters, but we would like to get the n - connections between them so that we can make observations based on that
# - Therfore, find_n_closest_characters takes the character_list and returns a list of tuples with [Character1, Character2, distance_between_them]

# %%
def find_n_closest_characters(character_list, text_cleaned, n):
    text_str = ""
    for _list in text_cleaned:
        for string in _list:
            text_str += string + ' '
    
    new_character_list = []
    for char1 in character_list:
        temp_characters = []
        index_c1 = text_str.find(char1["name"])
        if index_c1 >= 0:
            for char2 in character_list:
                if char1["name"] != char2["name"]:
                    idx_c2 = text_str.find(char2["name"], index_c1, len(text_str) - 1)
                    if idx_c2 > index_c1:
                        temp_characters.append((char1["name"], char2["name"], idx_c2 - index_c1))
            if temp_characters:
                temp_characters.sort(reverse=False, key = lambda x : x[2])
                new_character_list += temp_characters[:n]


    return new_character_list

# %%
n_characters = find_n_closest_characters(characters_list[:40], game_text_cleaned, 3)
print(n_characters)
# Out:
# [('Tyrion', 'Ned', 64), ('Tyrion', 'Robert', 453), ('Tyrion', 'Cersei', 659), ('Ned', 'Catelyn', 513), ('Ned', 'Catelyn Stark', 822), ('Ned', 'Stark', 830), ('Jon', 'Stark', 78), ('Jon', 'Starks', 78), ('Jon', 'Eddard Stark', 441), ('Catelyn', 'Ned', 690), ('Catelyn', 'Catelyn Stark', 1512), ('Catelyn', 'Stark', 1520), ('Dany', 'Viserys', 88), ('Dany', 'Khal Drogo', 555), ('Dany', 'Lannister', 1627), ('Jaime', 'Lannister', 6), ('Jaime', 'Sandor Clegane', 35), ('Jaime', 'Tyrion', 100), ('Robb', 'Mance', 25), ('Robb', 'Jon', 390), ('Robb', 'Stark', 468), ('Robert', 'Jon', 125), ('Robert', 'Jon Snow', 125), ('Robert', 'Robb', 465), ('Arya', 'Joffrey', 65), ('Arya', 'Jon', 81), ('Arya', 'Lannister', 264), ('Joffrey', 'Jon', 16), ('Joffrey', 'Lannister', 199), ('Joffrey', 'Jaime', 238), ('Sam', 'Jon', 72), ('Sam', 'Ned', 76), ('Sam', 'Grenn', 129), ('Stannis', 'Renly', 21), ('Stannis', 'Eddard Stark', 27), ('Stannis', 'Stark', 34), ('Lannister', 'Mormont', 6598), ('Lannister', 'Robb', 7023), ('Lannister', 'Mance', 7048), ('Cersei', 'Ned', 52), ('Cersei', 'Catelyn', 76), ('Cersei', 'Lannister', 84), ('Lysa', 'Catelyn', 5), ('Lysa', 'Ned', 37), ('Lysa', 'Luwin', 220), ('Luwin', 'Catelyn', 34), ('Luwin', 'Jon', 129), ('Luwin', 'Ned', 149), ('Khal Drogo', 'Dany', 179), ('Khal Drogo', 'Viserys', 833), ('Khal Drogo', 'Lannister', 1072), ('Tywin', 'Lannister', 6), ('Tywin', 'Jon', 25), ('Tywin', 'Ned', 51), ('Rodrik', 'Robb', 25), ('Rodrik', 'Robert', 84), ('Rodrik', 'Catelyn', 103), ('Bronn', 'Tyrion', 53), ('Bronn', 'Jaime', 220), ('Bronn', 'Stark', 716), ('Tyrion Lannister', 'Lannister', 7), ('Tyrion Lannister', 'Jon', 63), ('Tyrion Lannister', 'Ned', 592), ('Gregor', 'Renly', 956), ('Gregor', 'Barristan', 1657), ('Gregor', 'Sandor Clegane', 1690), ('Brienne', 'Jaime', 227), ('Brienne', 'Catelyn', 316), ('Brienne', 'Catelyn Stark', 316), ('Littlefinger', 'Catelyn', 19), ('Littlefinger', 'Rodrik', 142), ('Littlefinger', 'Lannister', 160), ('Grenn', 'Jon', 32), ('Grenn', 'Robb', 950), ('Grenn', 'Tyrion', 1356), ('Eddard Stark', 'Stark', 7), ('Eddard Stark', 'Robert', 187), ('Eddard Stark', 'Jon', 312), ('Stark', 'Lannister', 12), ('Stark', 'Mormont', 6610), ('Stark', 'Robb', 7035), ('Hodor', 'Robb', 271), ('Hodor', 'Arya', 301), ('Hodor', 'Luwin', 1020), ('Jon Snow', 'Robb', 340), ('Jon Snow', 'Robert', 984), ('Jon Snow', 'Catelyn', 4073), ('Mance', 'Robb', 360), ('Mance', 'Jon', 365), ('Mance', 'Stark', 443), ('Barristan', 'Jaime', 121), ('Barristan', 'Lannister', 127), ('Barristan', 'Robb', 163), ('Viserys', 'Dany', 73), ('Viserys', 'Khal Drogo', 467), ('Viserys', 'Lannister', 1539), ('Ygritte', 'Jon', 153), ('Ygritte', 'Mance', 673), ('Ygritte', 'Ned', 4482), ('Sandor Clegane', 'Tyrion', 65), ('Sandor Clegane', 'Ned', 129), ('Sandor Clegane', 'Robert', 518), ('Petyr', 'Rodrik', 23), ('Petyr', 'Catelyn', 88), ('Petyr', 'Ned', 290), ('Mormont', 'Robb', 425), ('Mormont', 'Mance', 450), ('Mormont', 'Jon', 815), ('Starks', 'Eddard Stark', 363), ('Starks', 'Robert', 550), ('Starks', 'Jon', 675), ('Catelyn Stark', 'Stark', 8), ('Catelyn Stark', 'Ned', 143), ('Catelyn Stark', 'Starks', 380), ('Renly', 'Eddard Stark', 6), ('Renly', 'Stark', 13), ('Renly', 'Robert', 19), ('Kevan', 'Tywin', 13), ('Kevan', 'Ned', 88), ('Kevan', 'Robert', 108)]

# %%
game_df = pd.DataFrame(n_characters, columns=["Character1", "Character2", "Distance"])
game_df
# Out:
#     Character1     Character2  Distance
# 0       Tyrion            Ned        64
# 1       Tyrion         Robert       453
# 2       Tyrion         Cersei       659
# 3          Ned        Catelyn       513
# 4          Ned  Catelyn Stark       822
# ..         ...            ...       ...
# 115      Renly          Stark        13
# 116      Renly         Robert        19
# 117      Kevan          Tywin        13
# 118      Kevan            Ned        88
# 119      Kevan         Robert       108
#
# [120 rows x 3 columns]

# %% [markdown]
# ## Once we have all the data available we start graphing
# -----

# %%
import networkx as nx
from siuba import count

# Create our Graph object
game_df_graph = count(game_df.head(120), 'Character1','Character2', 'Distance', sort=True)
game_df_graph.drop(columns=['Distance'])
G = nx.from_pandas_edgelist(df=game_df_graph, source='Character1', target='Character2', edge_attr='n')

import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

# Time to draw it
nx.draw(G, pos=nx.spring_layout(G, k=1.25, iterations=200), node_size=400, font_size=10, node_color='r', edge_color='b', with_labels=True)
figure(figsize=(2560, 1440))

plt.show()
